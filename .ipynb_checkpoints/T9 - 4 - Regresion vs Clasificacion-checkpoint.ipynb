# %% [markdown]
# # Clasificacion de Flores Iris

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn import svm, datasets

# %%
style.use('ggplot')
plt.rcParams['figure.figsize'] = (16,8)

# %%
iris = pd.read_csv('../python-ml-course-master/datasets/iris/iris.csv')
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
Species = ['setosa','virginica','versicolor']
tmp = []
for i in range(150):
    if iris['Species'][i]==Species[0]:
        tmp.append(0)
    elif iris['Species'][i]==Species[1]:
        tmp.append(1)
    else:
        tmp.append(2)

# %%
#Analizamos solo las primeras dos porque habian sido las mas importantes en el analisis del arbol
columns = iris.columns.values.tolist()
X = iris[columns[:2]]
Y = pd.DataFrame({'Species':tmp})

# %%
x_min,x_max = X['Sepal.Length'].min()-1 , X['Sepal.Length'].max()+1
y_min, y_max = X['Sepal.Width'].min()-1 , X['Sepal.Width'].max()+1
h = (x_max - x_min)/100

# %%
xx , yy = np.meshgrid(np.arange(x_min , x_max , h) , np.arange(y_min , y_max , h))

#parrilla de dibujo
x_plot = np.c_[xx.ravel(), yy.ravel()]

# %%
C = 1.0
svc = svm.SVC(kernel='linear', C=C, decision_function_shape='ovr')
svc = svc.fit(X,Y)
Ypred = svc.predict(x_plot)
Ypred = Ypred.reshape(xx.shape)
# Out:
# /home/santiago/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.contourf(xx,yy,Ypred, cmap=plt.cm.tab10 , alpha=0.3)
plt.scatter(X['Sepal.Length'] ,X['Sepal.Width'] , c=Y['Species'] )
plt.xlabel(' Longitud del petalo ')
plt.ylabel(' Anchura del patelo ')
plt.title(' Clasificacion SVC por kernel lineal ', size=30)
# Out:
# Text(0.5, 1.0, ' Clasificacion SVC por kernel lineal ')

# %%
C = 1.0
svc = svm.SVC(kernel='rbf', C=C, decision_function_shape='ovr')
svc = svc.fit(X,Y)
Ypred = svc.predict(x_plot)
Ypred = Ypred.reshape(xx.shape)
# Out:
# /home/santiago/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
plt.contourf(xx,yy,Ypred, cmap=plt.cm.tab10 , alpha=0.3)
plt.scatter(X['Sepal.Length'] ,X['Sepal.Width'] , c=Y['Species'] )
plt.xlabel(' Longitud del petalo ')
plt.ylabel(' Anchura del patelo ')
plt.title(' Clasificacion SVC por kernel RBF ', size=30)
# Out:
# Text(0.5, 1.0, ' Clasificacion SVC por kernel RBF ')

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.utils import shuffle

# %%
Xtrain, Xtest , Ytrain , Ytest = train_test_split(X,Y, test_size = 0.25)

# %%
parameters = [
    {
        'kernel':['rbf'],
        'gamma': [1e-4,1e-3,1e-2, 0.1 , 0.2 , 0.5],
        'C': [1,10,100,1000]
    },
    {
       'kernel':['linear'],
        'C': [1,10,100,1000] 
    }
]

# %%
clf = GridSearchCV(svm.SVC(decision_function_shape='ovr') , param_grid=parameters, cv=5)
clf.fit(Xtrain,Ytrain)
# Out:
# /home/santiago/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/santiago/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/santiago/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
clf.best_params_
# Out:
# {'C': 100, 'gamma': 0.5, 'kernel': 'rbf'}

# %%
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
params = clf.cv_results_['params']
for m, s, p in zip(means, stds, params):
    print("%0.3f (+/-%0.3f) para %r"%(m, 2*s, p))
# Out:
# 0.357 (+/-0.015) para {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.357 (+/-0.015) para {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.608 (+/-0.145) para {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.811 (+/-0.159) para {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.811 (+/-0.148) para {'C': 1, 'gamma': 0.2, 'kernel': 'rbf'}
# 0.793 (+/-0.151) para {'C': 1, 'gamma': 0.5, 'kernel': 'rbf'}
# 0.357 (+/-0.015) para {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.626 (+/-0.175) para {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.802 (+/-0.171) para {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 0.793 (+/-0.151) para {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 0.793 (+/-0.151) para {'C': 10, 'gamma': 0.2, 'kernel': 'rbf'}
# 0.803 (+/-0.149) para {'C': 10, 'gamma': 0.5, 'kernel': 'rbf'}
# 0.635 (+/-0.181) para {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.802 (+/-0.171) para {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.793 (+/-0.151) para {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# ...

# %%
Y_pred = clf.predict(Xtest)
print(classification_report(Y_pred,Ytest , target_names=Species))

# Presicion Verdaderos positivos
# RECALL = VerdaderosPositivos / (VerdaderosPositivos+FalsosNegativos)
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        12
#    virginica       0.75      0.71      0.73        17
#   versicolor       0.50      0.56      0.53         9
#
#     accuracy                           0.76        38
#    macro avg       0.75      0.75      0.75        38
# weighted avg       0.77      0.76      0.77        38
